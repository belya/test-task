# %%
import pandas as pd

# %%
listings_df = pd.read_csv("/home/anatoli/Документы/airbnb/listings.csv")

# %%
listings_df["price_value"] = listings_df["price"].apply(lambda x: x[1:].replace(",", "")).astype(float)

# %%
dataset_df = listings_df[listings_df["review_scores_rating"] >= 90][["room_type", "neighbourhood_cleansed", "price_value", "name", "description", "neighborhood_overview", "latitude", "longitude"]].copy()

# %%
# dataset_df = dataset_df.dropna()

# %%
avg_prices_df = dataset_df.groupby(["room_type", "neighbourhood_cleansed"])["price_value"].agg(["mean", "median", "std"]).reset_index()

# %%
avg_prices_df["max"] = avg_prices_df["mean"] + avg_prices_df["std"]

# %%
prices_map_df = avg_prices_df.set_index(["neighbourhood_cleansed", "room_type"])["mean"].unstack(-1)

# %%
prices_map_df.sort_values("Private room", ascending=False).iloc[0:10]
# Out:
# room_type               Entire home/apt  Hotel room  Private room  Shared room
# neighbourhood_cleansed
# Westminster                  206.954969  191.071429     82.647343    39.909091
# City of London               386.654054  168.000000     73.880000          NaN
# Kensington and Chelsea       178.025962  142.375000     73.761341    61.857143
# Hammersmith and Fulham       135.755054  156.600000     61.643695    47.111111
# Camden                       143.819528   63.434783     57.972914   112.583333
# Southwark                    137.912243   89.000000     57.265269   108.444444
# Richmond upon Thames         152.117021  132.750000     54.158385   112.500000
# Barking and Dagenham          80.636364         NaN     53.820755    40.000000
# Islington                    191.040398  106.000000     53.789195    37.200000
# Haringey                     115.080756   34.000000     53.611465    19.600000

# %%
merged_df = dataset_df.merge(avg_prices_df, on=["room_type", "neighbourhood_cleansed"])

# %%
merged_df["target"] = False
merged_df.loc[merged_df["price_value"]>= merged_df["max"], "target"] = True

# %%
merged_df.dropna(inplace=True)

# %%
merged_df["target"].value_counts()
# Out:
# False    28091
# True      1766
# Name: target, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.model_selection import train_test_split

# %%
train_indices, test_indices = train_test_split(merged_df.index, test_size=0.3)

# %%
merged_df["test"] = False
merged_df.loc[test_indices, "test"] = True

# %%
vectorizer = TfidfVectorizer(min_df=5, max_features=10000, stop_words='english')

# %%
merged_df["full_text"] = merged_df["description"] + " " +  merged_df["neighborhood_overview"]

# %%
def remove_tags(x):
    return x.replace("<", " ").replace(">", " ")

# %%
merged_df["full_text"] = merged_df["full_text"].apply(remove_tags)

# %%
X_train = vectorizer.fit_transform(merged_df[~merged_df["test"]]["full_text"])

# %%
X_test = vectorizer.transform(merged_df[merged_df["test"]]["full_text"])

# %%
y_train = merged_df[~merged_df["test"]]["target"]

# %%
y_test = merged_df[merged_df["test"]]["target"]

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import roc_auc_score

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
prediction_train = model.predict_proba(X_train).T[1]

# %%
X_test
# Out:
# <8958x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 816251 stored elements in Compressed Sparse Row format>

# %%
prediction_test = model.predict_proba(X_test).T[1]

# %%
roc_auc_score(y_train, prediction_train)
# Out:
# 0.901457451204206

# %%
roc_auc_score(y_test, prediction_test)
# Out:
# 0.8209212425701323

# %%
import eli5

# %%
eli5.explain_weights(model, feature_names=vectorizer.get_feature_names(), top=100)
# Out:
# Explanation(estimator='LogisticRegression()', description="\nFeatures with largest coefficients.\nCaveats:\n1. Be careful with features which are not\n   independent - weights don't show their importance.\n2. If scale of input features is different then scale of coefficients\n   will also be different, making direct comparison between coefficient values\n   incorrect.\n3. Depending on regularization, rare features sometimes may have high\n   coefficients; this doesn't mean they contribute much to the\n   classification result for most examples.\n", error=None, method='linear model', is_regression=False, targets=[TargetExplanation(target=True, feature_weights=FeatureWeights(pos=[FeatureWeight(feature='rooms', weight=3.4435655532102514, std=None, value=None), FeatureWeight(feature='family', weight=3.198713401017991, std=None, value=None), FeatureWeight(feature='bedrooms', weight=3.0535026008939568, std=None, value=None), FeatureWeight(feature='groups', weight=2.6872896528731784, std=None, value=None), FeatureWeight(feature='master', weight=2.5260032940584303, std=None, value=None), FeatureWeight(feature='stunning', weight=2.251091127646679, std=None, value=None), FeatureWeight(feature='shoreditch', weight=2.225689840158928, std=None, value=None), FeatureWeight(feature='families', weight=2.1893755425775123, std=None, value=None), FeatureWeight(feature='bbq', weight=2.079212990256357, std=None, value=None), FeatureWeight(feature='house', weight=2.0182600583549513, std=None, value=None), FeatureWeight(feature='sleeps', weight=2.005912303052661, std=None, value=None), FeatureWeight(feature='luxurious', weight=2.0050537292094894, std=None, value=None), FeatureWeight(feature='beds', weight=1.9215297522364898, std=None, value=None), FeatureWeight(feature='fireplace', weight=1.8943085792854397, std=None, value=None), FeatureWeight(feature='bathrooms', weight=1.8861720190710227, std=None, value=None), FeatureWeight(feature='parsons', weight=1.873353563749781, std=None, value=None), FeatureWeight(feature='penthouse', weight=1.7713300263952725, std=None, value=None), FeatureWeight(feature='home', weight=1.6496941495004809, std=None, value=None), FeatureWeight(feature='large', weight=1.6047520793661474, std=None, value=None), FeatureWeight(feature='group', weight=1.5952423425242155, std=None, value=None), FeatureWeight(feature='luxury', weight=1.5613544445545067, std=None, value=None), FeatureWeight(feature='suite', weight=1.556842735917935, std=None, value=None), FeatureWeight(feature='glass', weight=1.516796799494124, std=None, value=None), FeatureWeight(feature='croydon', weight=1.4772346847937121, std=None, value=None), FeatureWeight(feature='primrose', weight=1.4697746851808986, std=None, value=None), FeatureWeight(feature='ealing', weight=1.3870347291515708, std=None, value=None), FeatureWeight(feature='dining', weight=1.3845328469693006, std=None, value=None), FeatureWeight(feature='garden', weight=1.3774107051272848, std=None, value=None), FeatureWeight(feature='accommodation', weight=1.3676785252244268, std=None, value=None), FeatureWeight(feature='walls', weight=1.3578133873042593, std=None, value=None), FeatureWeight(feature='basement', weight=1.34207709283397, std=None, value=None), FeatureWeight(feature='wimbledon', weight=1.3006880671196084, std=None, value=None), FeatureWeight(feature='holland', weight=1.29656901084004, std=None, value=None), FeatureWeight(feature='chiswick', weight=1.2898648601817702, std=None, value=None), FeatureWeight(feature='cctv', weight=1.2840925936521679, std=None, value=None), FeatureWeight(feature='ensuite', weight=1.2667047950475023, std=None, value=None), FeatureWeight(feature='playroom', weight=1.2625554854376528, std=None, value=None), FeatureWeight(feature='barnes', weight=1.2534388974043582, std=None, value=None), FeatureWeight(feature='comfort', weight=1.2499787010633114, std=None, value=None), FeatureWeight(feature='designed', weight=1.2471352090772305, std=None, value=None), FeatureWeight( ...

# %%
import numpy as np

# %%
feature_names = np.array(vectorizer.get_feature_names())

# %%
best_features = feature_names[np.argsort(-model.coef_)][0, 0:500]

# %%
from tqdm import tqdm_notebook

# %%
regions = listings_df["neighbourhood_cleansed"].str.lower().unique().tolist()

# %%
found_places = []
all_found_places_df = []

for place in tqdm_notebook(best_features):
    place_indices = merged_df["neighborhood_overview"].str.lower().str.contains(place)
    place_df = merged_df[place_indices][["latitude", "longitude", "target", "price_value"]].copy()
    place_df["place"] = place
    if min(place_df[["latitude", "longitude"]].std() < 0.02):
        print(place)
        if any([place in region for region in regions]):
            print("Not included")
            continue
        found_places.append(place)
        all_found_places_df.append(place_df)
# Out:
# /home/anatoli/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: TqdmDeprecationWarning:
#
# This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=500.0), HTML(value='')))
# parsons
# leyton
# leytonstone
# fireplaces
# aldgate
# exmouth
# isleworth
# kensal
# closets
# wanstead
# goodmayes
# askew
# blitz
# aeltc
# chatsworth
# cricklewood
# maids
# skylights
# norbiton
# spitalfields
# chancery
# colleagues
# coulsdon
# marksman
# lgbtqia

# %%
found_places_df = pd.concat(all_found_places_df)

# %%
# listings_df["neighbourhood_cleansed"].value_counts()

# %%
index = merged_df["full_text"].str.lower().str.contains("chancery")
merged_df[index.fillna(False)]["full_text"].sample().iloc[0]
# Out:
# "Light & airy modern family home with fantastic garden in Bloomsbury, Zone 1, in the heart of London’s legal area close to Chancery Lane & Holborn. A vibrant area with restaurants, shops, markets, and close to four tube stations.  Easy walking distance to Lamb Conduit St, Exmouth Market, British Museum, Kings Cross & Granary Square, Farringdon, and also very close to Covent Garden, Soho, & Oxford St, Smithfield, the Barbican & short bus trips to Shoreditch, Hoxton, Borough Market & Camden Town. br /  br /  b The space /b  br / This is a 1st & 2nd floor light-filled family home in WC1, Zone 1, in a small privately owned apartment building, with a lift.  It is very spacious & comfortable with a fantastic garden to enjoy.   br /  br / Downstairs - Entrance hall, Lounge & kitchen (pictured), Shower room (pictured), Laundry room, Double bedroom (sofa bed), Conservatory dining room (pictured), Leafy garden with BBQ & dining area (pictured) with retractable awning. There's a large flatscreen s We are located in a fascinating area - Bloomsbury, known for its writers and actors (Charles Dickens lived around the corner where the Dickens Museum is now located) and Gray’s Inn, a historical legal district.  We are also just beside the quirky Lambs Conduit Street lined with edgy clothing and jewellery boutiques (Folk, Oliver Spence, The Dairy), and if you want to buy a diamond or two Hatton Garden is just down the road. We are also on the border of Clerkenwell, a stroll away from Exmouth Market (where you will find restaurants such as Moro, Morito, Caravan, Blackfoot, Medcalf and a food market on weekdays), Smithfield Meat Market which is full of restaurants (our favourite is Club Gascon), bars and clubs, and quick bus trips away from the vibrant areas of Islington and Shoreditch.  We are incredibly central yet our wonderful area has a village feel. Andrews, a traditional English cafe, is directly opposite us and open for breakfast onwards. Everything is on your doorstep here, you "

# %%
place_names = {'spitalfields': "Spitalfields",
 'chatsworth': 'Chatsworth',
 'kensal': 'Kensal',
 'leyton': 'Leyton',
 'exmouth': 'Exmouth',
 'parsons': 'Parsons Green',
 'aldgate': 'Aldgate',
 'wanstead': 'Wanstead',
 'leytonstone': "Leyton",
 'askew': 'Askew',
 'cricklewood': 'Cricklewood',
 'chancery': 'Chancery Lane',
 'coulsdon': 'Coulsdon',
 'isleworth': 'Isleworth',
 'norbiton': 'Norbiton',
 'marksman': 'The Marksman',
 'goodmayes': 'Goodmayes',
 'aeltc': 'aeltc'.upper()}

# %%
found_places_df["place_name"] = found_places_df["place"].apply(place_names.get)

# %%
import plotly.express as px

px.scatter_mapbox(found_places_df[~found_places_df["place_name"].isnull()], lat="latitude", lon="longitude", color="place_name", hover_name="place_name",
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=15, zoom=9, mapbox_style="stamen-terrain")
# Out:
# <div>                            <div id="cec3b6b5-c6eb-4993-adbb-cc42b257eed1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cec3b6b5-c6eb-4993-adbb-cc42b257eed1")) {                    Plotly.newPlot(                        "cec3b6b5-c6eb-4993-adbb-cc42b257eed1",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>place_name=Parsons Green<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green", "Parsons Green"], "lat": [51.60255, 51.47573, 51.479279999999996, 51.4787, 51.48042, 51.471940000000004, 51.47132, 51.4729, 51.48033, 51.47226, 51.47444, 51.471959999999996, 51.475190000000005, 51.48028, 51.474709999999995, 51.47598, 51.47263, 51.4735, 51.47439, 51.47952, 51.472970000000004, 51.47113, 51.47967, 51.475770000000004, 51.4761, 51.47381, 51.46913, 51.47063, 51.46843, 51.4763, 51.47044, 51.47534, 51.47041, 51.46826, 51.47645, 51.4766, 51.472590000000004, 51.47404, 51.48137, 51.47166, 51.47394, 51.46837, 51.47707, 51.47255, 51.468740000000004, 51.4732, 51.47161, 51.4748, 51.47749, 51.47146, 51.47383, 51.48041, 51.47598, 51.48223, 51.47183, 51.47902, 51.47116, 51.47544, 51.47305, 51.48157, 51.476079999999996, 51.47198, 51.469840000000005, 51.46716, 51.47807, 51.471140000000005, 51.47915, 51.47232, 51.4722, 51.47679, 51.48253, 51.47842, 51.4754, 51.47294, 51.46966, 51.48183, 51.47998, 51.47957, 51.47798, 51.47603, 51.47205, 51.47382, 51.47502, ...
