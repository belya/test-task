# %%
import eli5
# Out:
# /home/anatoli/.local/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/anatoli/.local/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import roc_auc_score

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

# %%
listings_df = pd.read_csv("/home/anatoli/Документы/airbnb/listings.csv")

# %%
listings_df["price_value"] = listings_df["price"].apply(lambda x: x[1:].replace(",", "")).astype(float)

# %%
listings_df["price_per_accommodation"] = listings_df["price_value"] / listings_df["accommodates"]

# %%
dataset_df = listings_df[
    (listings_df["review_scores_rating"] >= 90) & \
    (listings_df["accommodates"] < 3)
][["room_type", "neighbourhood_cleansed", "price_per_accommodation", "name", "description", "neighborhood_overview", "latitude", "longitude"]].copy()

# %%
avg_prices_df = dataset_df.groupby(["room_type", "neighbourhood_cleansed"])["price_per_accommodation"].agg(["mean", "median", "std"]).reset_index()

# %%
avg_prices_df["max"] = avg_prices_df["mean"] + avg_prices_df["std"]

# %%
prices_map_df = avg_prices_df.set_index(["neighbourhood_cleansed", "room_type"])["mean"].unstack(-1)

# %%
prices_map_df = prices_map_df.sort_values("Private room", ascending=False).iloc[0:20]

# %%
for c in prices_map_df.columns:
    prices_map_df[c] = prices_map_df[c].apply(lambda x: "{:.2f} $".format(x))
    prices_map_df[c] = prices_map_df[c].str.replace("nan \$", "")

# %%
prices_map_df.index.name = ""

# %%
prices_map_df.columns.name = ""

# %%
prices_map_df
# Out:
#                        Entire home/apt Hotel room Private room Shared room
#
# Westminster                    69.08 $    87.38 $      47.56 $     27.30 $
# Kensington and Chelsea         56.62 $    66.00 $      46.05 $     44.00 $
# Hammersmith and Fulham         46.19 $    54.92 $      37.73 $     26.39 $
# Southwark                      46.25 $                 35.88 $     25.00 $
# Barking and Dagenham           31.08 $                 33.44 $
# City of London                 58.10 $    84.00 $      33.10 $
# Camden                         55.73 $    34.94 $      32.44 $     98.79 $
# Haringey                       35.16 $    17.00 $      32.07 $     17.60 $
# Islington                      48.29 $    48.00 $      31.53 $     21.62 $
# Wandsworth                     42.88 $    56.00 $      31.38 $     30.00 $
# Richmond upon Thames           46.78 $    58.50 $      30.22 $     25.00 $
# Kingston upon Thames           31.55 $                 29.55 $     17.00 $
# Brent                          44.80 $    88.33 $      29.51 $     85.33 $
# Lewisham                       32.87 $                 29.34 $     35.45 $
# Hounslow                       41.50 $    83.00 $      28.85 $     24.00 $
# Harrow                         67.50 $                 28.46 $
# Tower Hamlets                  50.96 $    46.64 $      28.14 $     36.21 $
# Lambeth                        43.00 $    33.12 $      28.12 $     30.80 $
# Merton                         44.94 $                 28.00 $     25.12 $
# Barnet                         32.45 $   121.25 $      27.95 $     28.62 $

# %%
merged_df = dataset_df.merge(avg_prices_df, on=["room_type", "neighbourhood_cleansed"])

# %%
merged_df["target"] = False
merged_df.loc[merged_df["price_per_accommodation"] >= merged_df["max"], "target"] = True

# %%
merged_df.dropna(inplace=True)

# %%
merged_df["target"].value_counts()
# Out:
# False    15368
# True       915
# Name: target, dtype: int64

# %%
train_indices, test_indices = train_test_split(merged_df.index, test_size=0.3)

# %%
merged_df["test"] = False
merged_df.loc[test_indices, "test"] = True

# %%
vectorizer = TfidfVectorizer(min_df=5, max_features=10000, stop_words='english')

# %%
merged_df["full_text"] = merged_df["description"] + " " +  merged_df["neighborhood_overview"]

# %%
def remove_tags(x):
    return x.replace("<", " ").replace(">", " ")

# %%
merged_df["full_text"] = merged_df["full_text"].apply(remove_tags)

# %%
X_train = vectorizer.fit_transform(merged_df[~merged_df["test"]]["full_text"])

# %%
X_test = vectorizer.transform(merged_df[merged_df["test"]]["full_text"])

# %%
y_train = merged_df[~merged_df["test"]]["target"]

# %%
y_test = merged_df[merged_df["test"]]["target"]

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
prediction_train = model.predict_proba(X_train).T[1]

# %%
X_test
# Out:
# <4885x7887 sparse matrix of type '<class 'numpy.float64'>'
# 	with 419065 stored elements in Compressed Sparse Row format>

# %%
prediction_test = model.predict_proba(X_test).T[1]

# %%
roc_auc_score(y_train, prediction_train)
# Out:
# 0.906552101353414

# %%
roc_auc_score(y_test, prediction_test)
# Out:
# 0.6751013625789299

# %%
eli5.explain_weights(model, feature_names=vectorizer.get_feature_names(), top=100)
# Out:
# Explanation(estimator='LogisticRegression()', description="\nFeatures with largest coefficients.\nCaveats:\n1. Be careful with features which are not\n   independent - weights don't show their importance.\n2. If scale of input features is different then scale of coefficients\n   will also be different, making direct comparison between coefficient values\n   incorrect.\n3. Depending on regularization, rare features sometimes may have high\n   coefficients; this doesn't mean they contribute much to the\n   classification result for most examples.\n", error=None, method='linear model', is_regression=False, targets=[TargetExplanation(target=True, feature_weights=FeatureWeights(pos=[FeatureWeight(feature='ealing', weight=2.235872112297144, std=None, value=None), FeatureWeight(feature='barnes', weight=1.8180967274249262, std=None, value=None), FeatureWeight(feature='property', weight=1.7272996195948878, std=None, value=None), FeatureWeight(feature='stylish', weight=1.6481290659411008, std=None, value=None), FeatureWeight(feature='hotel', weight=1.610198454874298, std=None, value=None), FeatureWeight(feature='views', weight=1.5267752303966604, std=None, value=None), FeatureWeight(feature='croydon', weight=1.517352689625842, std=None, value=None), FeatureWeight(feature='comfort', weight=1.3566565154069945, std=None, value=None), FeatureWeight(feature='modern', weight=1.339114531052471, std=None, value=None), FeatureWeight(feature='islington', weight=1.2925231896183347, std=None, value=None), FeatureWeight(feature='accommodation', weight=1.2745861259888003, std=None, value=None), FeatureWeight(feature='walks', weight=1.2561918785700348, std=None, value=None), FeatureWeight(feature='looking', weight=1.1784791472659246, std=None, value=None), FeatureWeight(feature='luxurious', weight=1.1703488978063248, std=None, value=None), FeatureWeight(feature='stunning', weight=1.1385383652642382, std=None, value=None), FeatureWeight(feature='skyline', weight=1.1320939529129077, std=None, value=None), FeatureWeight(feature='throw', weight=1.1098385924840428, std=None, value=None), FeatureWeight(feature='designer', weight=1.0755000369285634, std=None, value=None), FeatureWeight(feature='penthouse', weight=1.0518852829774346, std=None, value=None), FeatureWeight(feature='visiting', weight=1.0512692906706846, std=None, value=None), FeatureWeight(feature='king', weight=1.049833634952621, std=None, value=None), FeatureWeight(feature='brick', weight=1.0465858390110032, std=None, value=None), FeatureWeight(feature='centre', weight=1.0347056968461006, std=None, value=None), FeatureWeight(feature='best', weight=1.0271670161396103, std=None, value=None), FeatureWeight(feature='luxury', weight=1.0259561193777067, std=None, value=None), FeatureWeight(feature='river', weight=1.0252501950515402, std=None, value=None), FeatureWeight(feature='provide', weight=1.0175630861544762, std=None, value=None), FeatureWeight(feature='nearest', weight=1.0130763101984261, std=None, value=None), FeatureWeight(feature='english', weight=0.9417188856577459, std=None, value=None), FeatureWeight(feature='angel', weight=0.9380393394224469, std=None, value=None), FeatureWeight(feature='box', weight=0.9316204137511612, std=None, value=None), FeatureWeight(feature='toiletries', weight=0.9290296063173166, std=None, value=None), FeatureWeight(feature='putney', weight=0.9214645769305709, std=None, value=None), FeatureWeight(feature='plan', weight=0.9199459370188616, std=None, value=None), FeatureWeight(feature='short', weight=0.9174508936054027, std=None, value=None), FeatureWeight(feature='old', weight=0.912171774221642, std=None, value=None), FeatureWeight(feature='city', weight=0.9031369170834566, std=None, value=None), FeatureWeight(feature='master', weight=0.9017829717383263, std=None, value=None), FeatureWeight(feature='suite', weight=0.8922756918908379, std=None, value=None), FeatureWeight(feature='surrounding', weight=0.8911596449611635, std=None, value=None), FeatureWeight(feature ...

# %%
import numpy as np

# %%
feature_names = np.array(vectorizer.get_feature_names())

# %%
best_features = feature_names[np.argsort(-model.coef_)][0, 0:200]

# %%
from tqdm import tqdm_notebook

# %%
regions = listings_df["neighbourhood_cleansed"].str.lower().unique().tolist()

# %%
found_places = []
all_found_places_df = []

for place in tqdm_notebook(best_features):
    place_indices = merged_df["neighborhood_overview"].str.lower().str.contains(place)
    place_df = merged_df[place_indices][["latitude", "longitude", "target", "price_per_accommodation", "mean"]].copy()
    place_df["place"] = place
    if min(place_df[["latitude", "longitude"]].std() < 0.02):
        print(place)
        if any([place in region for region in regions]):
            print("Not included")
            continue
        found_places.append(place)
        all_found_places_df.append(place_df)
# Out:
# /home/anatoli/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: TqdmDeprecationWarning:
#
# This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# barnes
# putney
# coulsdon
# duplex
# leyton
# hoxton
# pinner
# pitshanger
# beckenham
# sidcup
# clerkenwell
# heated
# samsung
# belsize
# leytonstone
# deptford

# %%
found_places_df = pd.concat(all_found_places_df)

# %%
found_places_df["price_per_accommodation_diff"] = (found_places_df["price_per_accommodation"] - found_places_df["mean"]) / found_places_df["mean"] * 100

# %%
# listings_df["neighbourhood_cleansed"].value_counts()

# %%
# index = merged_df["full_text"].str.lower().str.contains("amazon")
# merged_df[index.fillna(False)]["full_text"].sample().iloc[0]

# %%
found_places_df["place"].unique()
# Out:
# array(['barnes', 'putney', 'coulsdon', 'duplex', 'leyton', 'hoxton',
#        'pinner', 'pitshanger', 'beckenham', 'sidcup', 'clerkenwell',
#        'heated', 'samsung', 'belsize', 'leytonstone', 'deptford'],
#       dtype=object)

# %%
# place_names = {'spitalfields': "Spitalfields",
#  'chatsworth': 'Chatsworth',
#  'kensal': 'Kensal',
#  'leyton': 'Leyton',
#  'exmouth': 'Exmouth',
#  'parsons': 'Parsons Green',
#  'aldgate': 'Aldgate',
#  'wanstead': 'Wanstead',
#  'leytonstone': "Leyton",
#  'askew': 'Askew',
#  'cricklewood': 'Cricklewood',
#  'chancery': 'Chancery Lane',
#  'coulsdon': 'Coulsdon',
#  'isleworth': 'Isleworth',
#  'norbiton': 'Norbiton',
#  'marksman': 'The Marksman',
#  'goodmayes': 'Goodmayes',
#  'aeltc': 'aeltc'.upper()}
place_names = {
    feature: feature.capitalize()
    for feature in found_places_df["place"].unique()
    if feature not in ["duplex", "samsung", "heated"]
}

# %%
found_places_df["Place"] = found_places_df["place"].apply(lambda x: place_names.get(x))

# %%
# found_places_df.groupby("place").agg({
#     "price_per_accommodation": "mean",
#     "mean": "mean"
# })

# %%
import plotly.express as px

px.scatter_mapbox(found_places_df[~found_places_df["Place"].isnull()], lat="latitude", lon="longitude", color="Place", hover_name="Place",
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=15, zoom=9, mapbox_style="stamen-terrain")
# Out:
# <div>                            <div id="ea22144c-0b10-4836-910d-89d91718eb6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea22144c-0b10-4836-910d-89d91718eb6b")) {                    Plotly.newPlot(                        "ea22144c-0b10-4836-910d-89d91718eb6b",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Place=Barnes<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes", "Barnes"], "lat": [51.47912, 51.47664, 51.48072, 51.48115, 51.48148, 51.48121, 51.480709999999995, 51.48108, 51.50131, 51.49134, 51.50098, 51.504690000000004, 51.483470000000004, 51.464259999999996, 51.46278, 51.46445, 51.44741, 51.46294, 51.46282, 51.464290000000005, 51.46225, 51.46232, 51.45174, 51.466809999999995, 51.46505, 51.45935, 51.46433, 51.46467, 51.46853, 51.483990000000006, 51.468990000000005, 51.4687, 51.46587, 51.467259999999996, 51.47318, 51.485620000000004, 51.467690000000005, 51.48264, 51.486000000000004, 51.46962, 51.471540000000005, 51.46696, 51.47965, 51.464529999999996, 51.46887, 51.4858, 51.47033], "legendgroup": "Barnes", "lon": [-0.25942, -0.27024000000000004, -0.20881999999999998, -0.21016999999999997, -0.2092, -0.20998000000000003, -0.20998000000000003, -0.20813, -0.24195, -0.22283000000000003, -0.24225, -0.21899999999999997, -0.22315, -0.22713000000000003, -0.23626999999999998, -0.22987, -0.23920999999999998, -0.18882000000000002, -0.23515, -0.24818, -0.23260999999999998, -0.23278000000000001, -0.2525, -0.2326, -0.25222, -0.22784000000000001, -0.25188, -0.25565, -0.25519000000000003, -0.24483000000000002, -0.25568, -0.26145999999999997, -0.23481999999999997, -0.2575, -0.23936999999999997, -0.23635, -0.25772, -0.23596, -0.23417, -0.2506, -0.24628000000000003, -0.25317, -0.27925, -0.23469, -0.25283, -0.2364, -0.25654], "marker": {"color": "#636efa"}, "mode": "markers", "name": "Barnes", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Place=Putney<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", "Putney", ...
